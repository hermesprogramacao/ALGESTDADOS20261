# %% [markdown]
# <a href="https://colab.research.google.com/github/hermesprogramacao/ALGESTDADOS20261/blob/main/semana_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !2/03 a 16/03

# %%
a = 10
b = 3

print (a + b) # Adição > 13
print (a - b) # Subtração > 7
print (a * b) # Multiplicação > 30
print (a / b) # Divisão real > 3.333333
print (a // b) # Diisão int. > 3
print (a % b) # Modulo > 1 (resto de 10/3)
print (a ** b) # 1000
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1
# 1000

# %%
nota = 7.5

print(nota >= 6.0)
print(nota == 10.0)
print(nota != 5.0)
print(nota < 5.0)
# Out:
# True
# False
# True
# False

# %%
idade = 17
renda = 1500.0

print(idade >= 18 and renda >= 1200)
print(idade >= 18 or  renda >= 1200)
tem_debito = False
print(not tem_debito)
# Out:
# False
# True
# True

# %%
print(2 + 3 * 4)
print((2 + 3) * 4)
print(2 ** 3 ** 2 )
print(10 / 2 + 3)
print(10 / (2 + 3))

x = 3 + 2 * 4 > 10 and not False
print(x)
# Out:
# 14
# 20
# 512
# 8.0
# 2.0
# True

# %%
#Atividades
# 1 Declare duas variáveis a = 15 e b = 4. Calcule e exiba o resultado de todas as operações aritméticas: +, -, *, /, //, % e **.

a = 15
b = 4

print(a + b) # Adição > 13
print(a - b) # Subtração > 7
print(a * b) # Multiplicação > 30
print(a / b) # Divisão real > 3.333333
print(a // b) # Diisão int. > 3
print(a % b) # Modulo > 1 (resto de 10/3)
print(a ** b) # 1000
# Out:
# 19
# 11
# 60
# 3.75
# 3
# 3
# 50625

# %%
# 2 Um professor deseja dividir 37 alunos em grupos iguais de 5. Usando operadores aritméticos, descubra
a = 37
b = 5
print(a // b)
print(a % b)
# Out:
# 7
# 2

# %%
# 3 Calcule a área de um retângulo com base 8.5 e altura 3.2. Exiba o resultado com a mensagem
a = 8.5
b = 3.2
print(f'A área do retângulo é: {(a * b) :.2F}')
# Out:
# A área do retângulo é: 27.20

# %%
# 4.1  dado o valor:
segundos = 9875
#Use // e % para converter esse valor em horas, minutos e segundos. Exemplo de saída:
print(f'{(segundos // 60)//60} Horas {(segundos % 3600//60)} Minutos {9875 % 60} Segundos')
# Out:
# 2 Horas 44 Minutos 35 Segundos

# %%
# 4.2
segundos = 9875
minutos = segundos//60
segundos = segundos%60
horas =  minutos//60
minutos = minutos%60

print(f'{horas}h {minutos}m {segundos}s')
# Out:
# 2h 44m 35s

# %%
# 5 Calcule 2 ** 10
print(f'2 ** 10 - Essa operação representa que o 2 foi elevado a decima potência dando o resultado de: {2 ** 10 } ')

print(144 ** 0.5 )
# Out:
# 2 ** 10 - Essa operação representa que o 2 foi elevado a decima potência dando o resultado de: 1024
# 12.0

# %%
# 6 Crie uma variável:
Temp = 38.5
# se a temperatura é maior que 37.5
#se a temperatura é igual a 36.5
#se a temperatura é diferente de 40.0

print(Temp > 37.5)
print(Temp == 36.5)
print(Temp != 40)
# Out:
# True
# False
# True

# %%
# 7 Dados:
x = 10
y = 10
#Preveja o resultado antes de executar e depois confirme no Python:
print(x == y)
print(x != y)
print(x >= y)
print(x <= y + 1)
# Out:
# True
# False
# True
# True

# %%
# 8
nota = float(input(" digite a sua nota: "))
print( f' Ele foi aprovado? {nota>7}')
print( f' Ele está de recuperação? {(nota<7)and(nota>=5)}')
print( f' Ele foi reprovado? {nota<5}')

# %%
# 9

# %%
# 10 preço 49,90
print(f' Está no orçamento? {49.90 <= 50}')

# %%
# 11
idade = 18

print(f'Com {idade} anos pode votar? {idade >= 16}' )
# Out:
# True

# %%
# 12
renda = 3000
score = 1000

print(f'Meu score é {score} e minha renda {renda}. Empréstimo aprovado {score >= 700 and renda >= 2000}')
# Out:
# False

# %%
# 13 Um sistema libera acesso se o usuário for administrador ou tiver nível de acesso ≥ 3.
nivel_acesso = 4
nivel = int(input('Qual seu nivel de scesso?'))
admin = bool(input(' Você é administrador'))

print(f'Ascessop liberado?' {nivel_ascesso=3 or is-admin= True})
# Out:
# True

# %%
# 14 ?
chovendo = True
Temperatura >= 28

print(f'Está chovendo', {not chovendo}, '\nE temperaura é a maior que 25°?)', {Temperatura > 25})

# %%
# 15
True and True = True
True and False = False
False and True = False
False and False = False
# Out:
#   File "/tmp/ipykernel_3585/2032737325.py", line 2
#     True and True = True
#     ^
# SyntaxError: cannot assign to expression

# %%
# 16

print(5 + 2 * 3) # multiplicação depois soma/subtração
print((5 + 2) * 3) # parenteses e depois multiplicação
print(2 ** 3 ** 2) # potencia de esquerda para direita
print(10 - 4 / 2 + 1) # subtração depois soma e depois a divisão
# Out:
# 11
# 21
# 512
# 9.0

# %%
# 17
3 + 2 * 4 ** 2 - 1

print(4 ** 2)
print(2 * 16)
print(3 + 32)
print(35 - 1)
print(3 + 2 * 4 ** 2 - 1)
# Out:
# 16
# 32
# 35
# 34
# 34

# %%
# 18 ?
x = 4 + 3 * 2 > 9 and not (5 == 5)
print(x)
# resposta: para expressão and ser false, basta que uma das posições seja false

# %%
# 19 ?
a= (10 / 2) + 3
print(a)
not True or False

# %%
# 20
nota1 = 9.5
nota2 = 8.5

print({(nota1 + nota2)/2} and {nota1 >= 7 and nota2 >= 7})
# Out:
# {True}
