# %% [markdown]
# <a href="https://colab.research.google.com/github/hermesprogramacao/ALGESTDADOS20261/blob/main/fixa%C3%A7%C3%A3o_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1 #Calcule e exiba o resultado de todas as operações aritméticas: +, -, *, /, //, % e **.

a = 15
b = 4

print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
# Out:
# 19
# 11
# 60
# 3.75
# 3
# 3
# 50625

# %%
2#Um professor deseja dividir 37 alunos em grupos iguais de 5. Usando operadores aritméticos, descubra:

print(f' Formarão {37//5} grupos')
print(f'Sobrão {37%5}')
# Out:
#  Formarão 7 grupos
# Sobrão 2

# %%
#3 - Calcule a área de um retângulo com base 8.5 e altura 3.2. Exiba o resultado com a mensagem:
print(f'A área de retângulo é de {8.5*3.2 :.2f} cm2')
# Out:
# A área de retângulo é de 27.20 cm2

# %%
#4 - Dado o valor:
# segundos = 9875
# Use // e % para converter esse valor em horas, minutos e segundos. Exemplo de saída: 2h 44min 35seg

segundos = 9875
minutos = 9875//60
segundos = segundos%60
horas = minutos//60
minutos = minutos%60

print(f'{horas}h {minutos}m {segundos}s')
# Out:
# 2h 44m 35s

# %%
#5 - Calcule:
# 2 ** 10
# Explique com um comentário no código o que essa operação representa.
# R.: O número dois é elevado a sua 10ª potência

# Depois calcule a raiz quadrada de 144 usando potenciação
print(f'A raiz quadrada de 144  é de {144**0.5}')
# Out:
# A raiz quadrada de 144  é de 12.0

# %%
#6 - Crie uma variável:
temp = 38
#Use operadores relacionais para verificar:
# a - se a temperatura é maior que 37.5
print(temp > 37.5)
# b - se a temperatura é igual a 36.5
print(temp == 36.5)
# c - se a temperatura é diferente de 40.0
print(temp != 40)
# Out:
# True
# False
# True

# %%
# 7 - Dados:
x = 10
y = 10
# Preveja o resultado antes de executar e depois confirme no Python:
print(x == y) #True
print(x != y) #False
print(x >= y) #True
print(x <= y + 1) #True

print(x==y)
print(x!=y)
print(x>=y)
print(x<=y+1)
# Out:
# True
# False
# True
# True
# True
# False
# True
# True

# %%
#8 - Um aluno tirou nota 6.5. Usando operadores relacionais,
#verifique se ele: Use print() para exibir cada verificação.
#a - foi aprovado (>= 7.0)
nota = 4

print(f'Ele foi aprovado? {nota>=7}')
print(f'Ele está de recuperação? {(nota < 7) and (nota <= 5)}')
print(f'Ele foi reprovado? {nota<5}')
# Out:
# Ele foi aprovado? False
# Ele está de recuperação? True
# Ele foi reprovado? True

# %%
#9 - Declare:

# Compare:
# Explique o resultado com um comentário no código.
# False. Pois o a está em formato inteiro e o b em formato de String.

a = 5
b = "5"
print(f'{a==b} pois o A está em formato de bnumero ionteiro e o B em string')
# Out:
# False pois o A está em formato de bnumero ionteiro e o B em string

# %%
#10 - Crie um programa Verifique se o produto está dentro do orçamento de R$ 50,00 usando <=.
preço = 20

print(f'o produto está dentrpo do orçamento? {preço <= 50}')
# Out:
# o produto está dentrpo do orçamento? True
