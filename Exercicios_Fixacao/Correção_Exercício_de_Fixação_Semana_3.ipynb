# %% [markdown]
# <a href="https://colab.research.google.com/github/gnrochabr/ALGESTDADOS20261/blob/main/Exercicios_Fixacao/Corre%C3%A7%C3%A3o_Exerc%C3%ADcio_de_Fixa%C3%A7%C3%A3o_Semana_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1 - Declare duas variáveis a = 15 e b = 4.
#Calcule e exiba o resultado de todas as operações aritméticas: +, -, *, /, //, % e **.

a = 15
b = 4
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)

# %%
#2 - Um professor deseja dividir 37 alunos em grupos iguais de 5.
#Usando operadores aritméticos, descubra:
#a - quantos grupos completos serão formados
print(f'Formarão {37//5} grupos')
#b - quantos alunos sobrarão
print(f'Sobrarão {37%5} alunos')

# %%
#3 - Calcule a área de um retângulo com base 8.5 e altura 3.2. Exiba o resultado com a mensagem:
base = 8.5
altura = 3.2
print(f'A área do retângulo é: {(base*altura):.2f}')

# %%
#4 - Dado o valor:
# segundos = 9875
# Use // e % para converter esse valor em horas, minutos e segundos. Exemplo de saída: 2h 44min 35seg
segundos = 9875
minutos = segundos//60
segundos = segundos%60
horas = minutos//60
minutos = minutos%60
print(f'{horas}h {minutos}m e {segundos}s')

# %%
#5 - Calcule:
# 2 ** 10
# Explique com um comentário no código o que essa operação representa.
# R.: O número dois é elevado a sua 10ª potência

# Depois calcule a raiz quadrada de 144 usando potenciação.
print(f'A raiz de 144 é {144**(1/2)}')

# %%
#6 - Crie uma variável:
temperatura = 38.5

# Use operadores relacionais para verificar:
# a - se a temperatura é maior que 37.5
print(temperatura>37.5)

# b - se a temperatura é igual a 36.5
print(temperatura==36.5)

# c - se a temperatura é diferente de 40.0
print(temperatura!=40)

# %%
# 7 - Dados:
x = 10
y = 10
# Preveja o resultado antes de executar e depois confirme no Python:
print(x == y) #True
print(x != y) #False
print(x >= y) #True
print(x <= y + 1) #True

# %%
#8 - Um aluno tirou nota 6.5. Usando operadores relacionais,
#verifique se ele: Use print() para exibir cada verificação.
nota = 6.5
#a - foi aprovado (>= 7.0)
print(f'Ele foi aprovado? {nota>=7}')
#b - está em recuperação (>= 5.0 e < 7.0)
print(f'Ele está de recuperação? {(nota<7)and(nota>=5)}')
#c - foi reprovado (< 5.0)
print(f'Ele foi reprovado? {nota<5}')

# %%
#9 - Declare:
a = 5
b = "5"
# Compare:
a == b
# Explique o resultado com um comentário no código.
# False. Pois o a está em formato inteiro e o b em formato de String.

# %%
#10 - Crie um programa com:
preco = 49.90
# Verifique se o produto está dentro do orçamento de R$ 50,00 usando <=.
print(f'Está no orçamento? {preco <= 50}')
# Out:
# Está no orçamento? True

# %%
#11 - Uma pessoa pode votar se tiver 16 anos ou mais.
idade = 15
#Use operadores lógicos para verificar se ela não pode votar.
print(f'Com {idade} anos pode votar? {idade>=16}')
#Depois teste com:
idade = 18
print(f'Com {idade} anos pode votar? {idade>=16}')
# Out:
# Com 15 anos pode votar? False
# Com 18 anos pode votar? True

# %%
#12 - Um empréstimo é aprovado se:
# renda >= 2000
# score >= 700
# Teste pelo menos três combinações diferentes usando and.

# Teste 1
renda = 1900 #renda menor
score = 500 #score menor
print(f'Meu score é {score} e minha renda é R${renda}. Empréstimo aprovado? {score >= 700 and renda >= 2000}')

# Teste 2
renda = 4000 #renda maior
score = 700 #score igual
print(f'Meu score é {score} e minha renda é R${renda}. Empréstimo aprovado? {score >= 700 and renda >= 2000}')

# Teste 3
renda = 1500 #renda maior
score = 850 #score menor
print(f'Meu score é {score} e minha renda é R${renda}. Empréstimo aprovado? {score >= 700 and renda >= 2000}')
# Out:
# Meu score é 500 e minha renda é R$1900. Empréstimo aprovado? False
# Meu score é 700 e minha renda é R$4000. Empréstimo aprovado? True
# Meu score é 850 e minha renda é R$1500. Empréstimo aprovado? False

# %%
#13 - Um sistema libera acesso se o usuário for administrador ou tiver nível de acesso ≥ 3.
# is_admin = False
# nivel_acesso = 4
# Use o operador or.

# Se for pedir para o usuário digitar:
# nivel_acesso = int(input('Qual seu nível de acesso? '))
# is_admin = bool(input('Você é administrador?'))

#Usando o exemplo do exercício
is_admin = False
nivel_acesso = 4
print(f'Acesso liberado? {nivel_acesso>=3 or is_admin==True}')
# Out:
# Acesso liberado? True

# %%
#14 - Dado:
chovendo = True
# Use not para verificar se não está chovendo. Depois combine com uma verificação de temperatura maior que 25.
temperatura = 28
print(f'Está chovendo? {not chovendo} \nTemperatura é maior que 25°C? {temperatura>25}')
# Out:
# Está chovendo? False
# Temperatura é maior que 25°C? True

# %%
#15 Monte manualmente a tabela-verdade do operador and:
print('Tabela-verdade do operador AND')
print('  A           B         C')
print(f'True   and  True   =  {True and True}')
print(f'True   and  False  =  {True and False}')
print(f'False  and  True   =  {False and True}')
print(f'False  and  False  =  {False and False}')
# Out:
# Tabela-verdade do operador AND
#   A           B         C
# True   and  True   =  True
# True   and  False  =  False
# False  and  True   =  False
# False  and  False  =  False

# %%
#16 - Calcule manualmente antes de executar:
#a - 5 + 2 * 3 #11
#b - (5 + 2) * 3 #21
#c - 2 ** 3 ** 2 #512
#d - 10 - 4 / 2 + 1 #9

#Explique a ordem de execução nos comentários.
print(5 + 2 * 3) #11
print((5 + 2) * 3) #21
print(2 ** 3 ** 2) #512
print(10 - 4 / 2 + 1) #9
# Out:
# 11
# 21
# 512
# 9.0

# %%
#17 - Resolva passo a passo:
resultado = 3 + 2 * 4 ** 2 - 1
#1° passo > 4 ** 2 = 16 ou seja, resultado = 3 + 2 * 16 - 1
#2° passo > 16 * 2 = 32 ou seja, resultado = 3 + 32 - 1
#3° passo > 3 + 32 - 1 = 34 ou seja, resultado = 34
print(resultado)

#Reescreva usando parênteses para mostrar a ordem das operações.
resultado = 3 + (2 * (4 ** 2)) - 1
# Out:
# 34

# %%
#18 - Analise o resultado da expressão abaixo antes de executar:
x = 4 + 3 * 2 > 9 and not (5 == 5)
print(x)
#Resposta: Para a expressão AND ser False, basta que uma das proposições "not(5==5)" seja False
# Out:
# False

# %%
#19 - Reescreva usando parênteses para obter os resultados indicados:
a = 10 / (2 + 3)
print(a) #2

b = not (True or False)
print(b) #False

# %%
#20 - Crie uma expressão que use operadores aritméticos, relacionais e lógicos para resolver o problema:
#Um estudante é aprovado com distinção se a média de duas notas for maior ou igual a 9.0
#e nenhuma das notas for menor que 7.0.

nota1 = 9.5
nota2 = 8.5
media = (nota1 + nota2) / 2 #média de duas notas
print(f'Está Aprovado? {media>=9 and nota1 >= 7 and nota2 >=7}')
